# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import random
import pickle as pkl

# %%
df = pd.read_pickle("..\\datasets\\tweets_cleaned_lemma_stopwords.pkl.gz")

# %%
tweets = df.tweet.to_list()
RANDOM_SEED = 42
np.random.seed(RANDOM_SEED)
random.Random(RANDOM_SEED).shuffle(tweets)

train_tweets, test_tweets = train_test_split(tweets, train_size=0.8)


vectorizer = CountVectorizer(min_df=2, max_df=0.95, max_features=4000)
train_counts = vectorizer.fit_transform(train_tweets)
test_counts = vectorizer.transform(test_tweets)

# %%
import plotly.express as px
counts = np.array(train_counts.sum(axis=0)).squeeze()

counts_sorted = np.sort(counts)[::-1]

values = np.cumsum(counts_sorted)

loss = -(values - np.sum(counts_sorted)) / np.sum(counts_sorted)

fig = px.line(loss)
fig.show(renderer='browser')

# %%
with open(f"vectorizer_4000.pkl.gz", "wb") as vec_file:
    pkl.dump(vectorizer, vec_file, protocol=pkl.HIGHEST_PROTOCOL)

# %%
with open("lda_results.csv", "wt") as f:
    f.write("components;train;test\n")

    for k_components in [10, 15, 20, 25, 30]:
        print(f"Fitting {k_components}")
        lda = LatentDirichletAllocation(n_components=k_components, random_state=42, verbose=True, evaluate_every=10, n_jobs=15, max_iter=100)
        lda.fit(train_counts)
        
        train_perplexity = lda.perplexity(train_counts)
        test_perplexity = lda.perplexity(test_counts)
        f.write(f"{k_components};{train_perplexity};{test_perplexity}\n")
        f.flush()
        with open(f"lda_{k_components}.pkl.gz", "wb") as model_file:
            pkl.dump(lda, model_file, protocol=pkl.HIGHEST_PROTOCOL)
# Out:
# Fitting 10
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 1827.5571
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100, perplexity: 1761.9150
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100, perplexity: 1747.1276
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100, perplexity: 1744.7313
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100, perplexity: 1743.1133
# iteration: 51 of max_iter: 100
# iteration: 52 of max_iter: 100
# iteration: 53 of max_iter: 100
# iteration: 54 of max_iter: 100
# iteration: 55 of max_iter: 100
# iteration: 56 of max_iter: 100
# iteration: 57 of max_iter: 100
# iteration: 58 of max_iter: 100
# iteration: 59 of max_iter: 100
# iteration: 60 of max_iter: 100, perplexity: 1742.1587
# iteration: 61 of max_iter: 100
# iteration: 62 of max_iter: 100
# iteration: 63 of max_iter: 100
# iteration: 64 of max_iter: 100
# iteration: 65 of max_iter: 100
# iteration: 66 of max_iter: 100
# iteration: 67 of max_iter: 100
# iteration: 68 of max_iter: 100
# iteration: 69 of max_iter: 100
# iteration: 70 of max_iter: 100, perplexity: 1741.4882
# iteration: 71 of max_iter: 100
# iteration: 72 of max_iter: 100
# iteration: 73 of max_iter: 100
# iteration: 74 of max_iter: 100
# iteration: 75 of max_iter: 100
# iteration: 76 of max_iter: 100
# iteration: 77 of max_iter: 100
# iteration: 78 of max_iter: 100
# iteration: 79 of max_iter: 100
# iteration: 80 of max_iter: 100, perplexity: 1741.4618
# Fitting 15
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 1948.0315
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100, perplexity: 1897.6456
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100, perplexity: 1892.0799
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100, perplexity: 1891.7702
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100, perplexity: 1891.8397
# Fitting 20
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 2048.6742
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100, perplexity: 2020.5563
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100, perplexity: 2023.9645
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100, perplexity: 2023.1394
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100, perplexity: 2023.1520
# Fitting 25
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 2159.7942
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100, perplexity: 2155.8565
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100, perplexity: 2159.3233
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100, perplexity: 2160.7434
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100, perplexity: 2160.7741
# Fitting 30
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 2272.6189
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100, perplexity: 2282.7258
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100, perplexity: 2286.4650
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100, perplexity: 2286.3272
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100, perplexity: 2286.6383
# iteration: 51 of max_iter: 100
# iteration: 52 of max_iter: 100
# iteration: 53 of max_iter: 100
# iteration: 54 of max_iter: 100
# iteration: 55 of max_iter: 100
# iteration: 56 of max_iter: 100
# iteration: 57 of max_iter: 100
# iteration: 58 of max_iter: 100
# iteration: 59 of max_iter: 100
# iteration: 60 of max_iter: 100, perplexity: 2286.6395

# %%
with open("vectorizer_4000.pkl.gz", "rb") as f:
    vectorizer = pkl.load(f)

with open("lda_15.pkl.gz", "rb") as f:
    lda = pkl.load(f)

# %%
import numpy as np
top_words_indices = np.argsort(lda.components_)[:, ::-1]

# %%
top_words = np.array(vectorizer.get_feature_names())[top_words_indices]

# %%
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_columns', None)
pd.DataFrame(top_words[:, :30])
# Out:
#                  0             1            2                3            4   \
# 0              sejm    posiedzieć       ustrój           sprawa      komenda
# 1               knf  sądnajwyższy      fabryka          słabość       sprawa
# 2        dziesiątka     spotkanie      dożynki      mieszkaniec        linia
# 3           reakcja      minister     pretekst         rządzący          pis
# 4    partiaobciachu      człowiek   kuchciński     kwintesencja        wyraz
# 5             pobić      debatape         stan              tvn       święto
# 6        wybory2019       miejsce        świat           rozpad   wypoczynek
# 7      prezydentura       justyna  kondolencja           zdobyć        szlak
# 8              czas       prolife       strona         udzielić       import
# 9          pieniądz        pomysł       bulwar  polskajestjedna     rządzący
# 10        priorytet    warszawiak       miasto            kamil           dt
# 11        rolnictwo         osoba    telewizor           dzieło    przysięga
# 12          działać      niszczeć     brazylia              rok         chór
# 13  polskajestjedna           pis   państwopis      preferencja  ugrupowanie
# 14         człowiek      półfinał        prawo        procedura    polowanie
#
#                  5               6              7          8   \
# 0               pis          słońce           prom     zmiana
# 1            opieka     preferencja          zgoda      rodak
# 2           kolumna              kp  samorządowiec        sld
# 3          nagranie           tychy       morderca     teczka
# 4        wybory2015         kuźmiuk     ignorancja      część
# 5           turysta           radio   pozdrowienie   imperium
# 6         zdarzenie  niekompetencja         puszka     sondaż
# 7            henryk       kalendarz            pis     medium
# 8        gospodarka           gmach          dolar  platforma
# 9            środek             rpo      filozofia   praktyka
# 10  polskajestjedna         andrzej          szafa   popierać
# 11          komórka        kowalski      dyrektywa   ojczyzna
# 12               gp           życie     referendum      dzien
# 13       właściciel            pole             eu    kościół
# 14          zdrowie        praktyka          wanda  odpowiedź
#
#                      9             10              11                12  \
# 0                 radna  wnioskodawca           marsz              góra
# 1              promować  politechnika     timmermansa          żołnierz
# 2   koalicjaobywatelska       budować  klimatnazmianę         glapiński
# 3               szefowa       miesiąc         machina            wiedza
# 4               pogrzeb       cenzura      terytorium  pomorzezachodnie
# 5                  publ     magdalena    aresztowanie             wiatr
# 6               myśliwy          szef         wroclaw              pech
# 7              rzecznik        janina        długopis         naukowiec
# 8                połowa   wydawnictwo       prowadzić         powstanie
# 9              podatnik         gowin             gol          centrala
# 10            spotkanie        gazeta          dubler              mecz
# 11             sytuacja        wielki          nakład          życzenie
# 12           wprowadzać        offset         ratować       nieobecność
# 13              polonia      rządzący      demokracja          opowieść
# 14              szantaż       ochrona          służba             sztab
#
#               13              14                 15           16  \
# 0           post           senat     uzdrowićpolskę           rt
# 1          radom       dedykacja        wyróżnienie    bohaterka
# 2      powietrze       regulamin             zespół    wstrzymać
# 3         sprawa       wielkanoc             spółka         plan
# 4         ulotka          realia  wolnemediawsejmie     instytut
# 5         odwaga        trudność                 fm        mucha
# 6         minuta     konieczność             bełkot  mistrzostwo
# 7   wiarygodność        festiwal        europejczyk        konto
# 8        materia          senior            program     ekonomia
# 9     państwopis        kosiniak        ugrupowanie  prawakobiet
# 10   mieszkaniec    lepszapolska              łóżko    kalendarz
# 11       liberał         nazista          terroryzm      religia
# 12      pandemia  rodzina500plus           karolina          cóż
# 13      obywatel            usta                upa    polowanie
# 14           typ           dział        bezczelność       sprawa
#
#               17              18                 19             20  \
# 0    preferencja           jutro     parlamentaryzm        gwiazda
# 1   podsumowanie            sens            juncker           król
# 2        ranking          wojsko            gwiazda       wrzesień
# 3      poznaniak           afera             monika           wola
# 4          lotos       turystyka  dotrzymujemysłowa          level
# 5          wirus          aparat          tożsamość  zamachlipcowy
# 6            fin  zaprzysiężenie            wieczor         wesele
# 7            bój      przyjmować             ziemia    wysłuchanie
# 8           moda     oglądalność               tusk        salon24
# 9             pl           rywal             system    przedstawić
# 10     większość            noga         podpowiedź          wejść
# 11        finisz            tort              grono     dyplomacja
# 12   wyprowadzić       szczecina            mateusz            miś
# 13         worek       rostowski          ukrainiec         zasięg
# 14    środowisko           życie              korea       rządzący
#
#                   21            22          23              24            25  \
# 0            poprzeć       senator  stanowisko        praktyka          pech
# 1               ręka         jajko      ziobro          wojtek         artur
# 2           praktyka          gust  internauta          klasyk   inauguracja
# 3        konsultacja  samopoczucie    newsweek            tvp3    wiceprezes
# 4             manifa          liga     nazywać             cba    posterunek
# 5               spór           pbs    retoryka          domena  poszanowanie
# 6             teresa     nienawiść        miał            pole     zakażenie
# 7     dobragospodyni       uczucie      ojciec         projekt    zwycięstwo
# 8               klip      wielkość   telewizor       gospodarz       telefon
# 9             frazes          etat   celebryta     rozwiązywać         wódka
# 10       trzaskowski      trybunał       akcja            rajd            rt
# 11  odpowiedzialność         krzyż          na     konstrukcja      twietter
# 12            śmierć  krasnodębski        żona            skok     możliwość
# 13        instrument     konkurent      obrona  sprawiedliwość       niemiec
# 14             legia          pole      milion      potępienie       zwierzę
#
#              26          27          28            29
# 0      opowieść    niepokój   więzienie         marka
# 1         cześć    promocja  legislacja          tryb
# 2      limuzyna        unia      okrzyk        radość
# 3     obietnica        echo  samoobrona  ministerstwo
# 4        spokój      metoda  stypendium         hotel
# 5     grudziądz     związek    wincenty  ruchnarodowy
# 6        komuna       filip   magdalena          azyl
# 7   przekroczyć      tysiąc   gosiewska        robota
# 8          anta          at     komórka        węgier
# 9       cameron       rondo       elita       karetka
# 10    wspólnota      pawlak      emeryt         serce
# 11      student     półtora       życie     urodzenie
# 12        farsa     wdrażać  ogłoszenie            tv
# 13      brygada        okno  pomówienie       warunki
# 14        panel  energetyka     katolik      sytuacja

# %%
def predict(lda, vectorizer, texts):
    counts = vectorizer.transform(texts)
    probas = lda.transform(counts)
    labels = np.argmax(probas, axis=1)
    return labels

def show_random_k_tweets_from_each_class(lda, vectorizer, texts, k=10):
    labels = np.arange(0, np.shape(lda.components_)[0])
    predictions = predict(lda, vectorizer, texts)
    for label in labels:
        topic_texts = np.array(texts)[predictions==label]
        k_texts = np.random.choice(topic_texts, k, replace=False)

# %%
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
import pandas as pd
import numpy as np
import random
import pickle as pkl

df = pd.read_pickle("..\\datasets\\tweets_cleaned_lemma_stopwords.pkl.gz")

tweets = df.tweet.to_list()

vectorizer = CountVectorizer(min_df=2, max_df=0.95, max_features=4000)
counts = vectorizer.fit_transform(tweets)

with open(f"vectorizer_4000_all.pkl.gz", "wb") as vec_file:
    pkl.dump(vectorizer, vec_file, protocol=pkl.HIGHEST_PROTOCOL)

lda = LatentDirichletAllocation(n_components=15, random_state=42, verbose=True, evaluate_every=10, n_jobs=15, max_iter=100)
lda.fit(counts)
# Out:
# iteration: 1 of max_iter: 100
# iteration: 2 of max_iter: 100
# iteration: 3 of max_iter: 100
# iteration: 4 of max_iter: 100
# iteration: 5 of max_iter: 100
# iteration: 6 of max_iter: 100
# iteration: 7 of max_iter: 100
# iteration: 8 of max_iter: 100
# iteration: 9 of max_iter: 100
# iteration: 10 of max_iter: 100, perplexity: 1874.7515
# iteration: 11 of max_iter: 100
# iteration: 12 of max_iter: 100
# iteration: 13 of max_iter: 100
# iteration: 14 of max_iter: 100
# iteration: 15 of max_iter: 100
# iteration: 16 of max_iter: 100
# iteration: 17 of max_iter: 100
# iteration: 18 of max_iter: 100
# iteration: 19 of max_iter: 100
# iteration: 20 of max_iter: 100, perplexity: 1832.7209
# iteration: 21 of max_iter: 100
# iteration: 22 of max_iter: 100
# iteration: 23 of max_iter: 100
# iteration: 24 of max_iter: 100
# iteration: 25 of max_iter: 100
# iteration: 26 of max_iter: 100
# iteration: 27 of max_iter: 100
# iteration: 28 of max_iter: 100
# iteration: 29 of max_iter: 100
# iteration: 30 of max_iter: 100, perplexity: 1826.0008
# iteration: 31 of max_iter: 100
# iteration: 32 of max_iter: 100
# iteration: 33 of max_iter: 100
# iteration: 34 of max_iter: 100
# iteration: 35 of max_iter: 100
# iteration: 36 of max_iter: 100
# iteration: 37 of max_iter: 100
# iteration: 38 of max_iter: 100
# iteration: 39 of max_iter: 100
# iteration: 40 of max_iter: 100, perplexity: 1824.9769
# iteration: 41 of max_iter: 100
# iteration: 42 of max_iter: 100
# iteration: 43 of max_iter: 100
# iteration: 44 of max_iter: 100
# iteration: 45 of max_iter: 100
# iteration: 46 of max_iter: 100
# iteration: 47 of max_iter: 100
# iteration: 48 of max_iter: 100
# iteration: 49 of max_iter: 100
# iteration: 50 of max_iter: 100, perplexity: 1824.0952
# iteration: 51 of max_iter: 100
# iteration: 52 of max_iter: 100
# iteration: 53 of max_iter: 100
# iteration: 54 of max_iter: 100
# iteration: 55 of max_iter: 100
# iteration: 56 of max_iter: 100
# iteration: 57 of max_iter: 100
# iteration: 58 of max_iter: 100
# iteration: 59 of max_iter: 100
# iteration: 60 of max_iter: 100, perplexity: 1823.2413
# iteration: 61 of max_iter: 100
# iteration: 62 of max_iter: 100
# iteration: 63 of max_iter: 100
# iteration: 64 of max_iter: 100
# iteration: 65 of max_iter: 100
# iteration: 66 of max_iter: 100
# iteration: 67 of max_iter: 100
# iteration: 68 of max_iter: 100
# iteration: 69 of max_iter: 100
# iteration: 70 of max_iter: 100, perplexity: 1823.2992
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-16-d8d357448311> in <module>
#      19 lda = LatentDirichletAllocation(n_components=15, random_state=42, verbose=True, evaluate_every=10, n_jobs=15, max_iter=100)
#      20 lda.fit(counts)
# ---> 21 f.write(f"{k_components};{train_perplexity};{test_perplexity}\n")
#      22 f.flush()
#      23 with open(f"lda_{15}_all.pkl.gz", "wb") as model_file:
#
# ValueError: I/O operation on closed file.

# %%
with open(f"lda_{15}_all.pkl.gz", "wb") as model_file:
    pkl.dump(lda, model_file, protocol=pkl.HIGHEST_PROTOCOL)
